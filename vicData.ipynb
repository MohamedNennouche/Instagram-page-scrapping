# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
posts_df = pd.read_csv('vic_post_data.csv', index_col='upload_date', parse_dates=True)
posts_df.head()
# Out:
#                      Unnamed: 0                   id    shortcode  height  \
# upload_date
# 2022-02-06 20:22:15           0  2767865786572748858  CZpb0SioDg6    1080
# 2022-02-04 16:58:26           1  2766313645664210939  CZj65qrIY_7    1080
# 2022-01-14 18:34:46           2  2751141848341905424  CYuBO9VIYAQ    1080
# 2022-01-12 10:59:21           3  2749463072730020401  CYoDhjtIHox     750
# 2022-01-01 18:57:57           4  2741722520276104531  CYMjhsdvvVT    1920
#
#                      width  gating_info  fact_check_overall_rating  \
# upload_date
# 2022-02-06 20:22:15   1080          NaN                        NaN
# 2022-02-04 16:58:26   1080          NaN                        NaN
# 2022-01-14 18:34:46   1080          NaN                        NaN
# 2022-01-12 10:59:21    750          NaN                        NaN
# 2022-01-01 18:57:57   1080          NaN                        NaN
#
#                      fact_check_information  sensitivity_friction_info  \
# upload_date
# 2022-02-06 20:22:15                     NaN                        NaN
# 2022-02-04 16:58:26                     NaN                        NaN
# 2022-01-14 18:34:46                     NaN                        NaN
# 2022-01-12 10:59:21                     NaN                        NaN
# 2022-01-01 18:57:57                     NaN                        NaN
#
#                      media_overlay_info  ... viewer_in_photo_of_you  \
# upload_date                              ...
# 2022-02-06 20:22:15                 NaN  ...                  False
# 2022-02-04 16:58:26                 NaN  ...                  False
# 2022-01-14 18:34:46                 NaN  ...                  False
# 2022-01-12 10:59:21                 NaN  ...                  False
# 2022-01-01 18:57:57                 NaN  ...                  False
#
#                     viewer_can_reshare  \
# upload_date
# 2022-02-06 20:22:15               True
# 2022-02-04 16:58:26               True
# 2022-01-14 18:34:46               True
# 2022-01-12 10:59:21               True
# 2022-01-01 18:57:57               True
#
#                                                              video_url  \
# upload_date
# 2022-02-06 20:22:15                                                NaN
# 2022-02-04 16:58:26                                                NaN
# 2022-01-14 18:34:46                                                NaN
# 2022-01-12 10:59:21                                                NaN
# 2022-01-01 18:57:57  https://z-p4-instagram.falg2-2.fna.fbcdn.net/v...
#
#                      has_audio video_view_count username  \
# upload_date
# 2022-02-06 20:22:15        NaN              NaN  vic.enp
# 2022-02-04 16:58:26        NaN              NaN  vic.enp
# 2022-01-14 18:34:46        NaN              NaN  vic.enp
# 2022-01-12 10:59:21        NaN              NaN  vic.enp
# 2022-01-01 18:57:57       True           4143.0  vic.enp
#
#                                     full_name  \
# upload_date
# 2022-02-06 20:22:15  Vision & Innovation Club
# 2022-02-04 16:58:26  Vision & Innovation Club
# 2022-01-14 18:34:46  Vision & Innovation Club
# 2022-01-12 10:59:21  Vision & Innovation Club
# 2022-01-01 18:57:57  Vision & Innovation Club
#
#                                                        profile_pic_url  \
# upload_date
# 2022-02-06 20:22:15                                                NaN
# 2022-02-04 16:58:26                                                NaN
# 2022-01-14 18:34:46                                                NaN
# 2022-01-12 10:59:21                                                NaN
# 2022-01-01 18:57:57  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
#
#                      profile_pic_url_hd  \
# upload_date
# 2022-02-06 20:22:15                 NaN
# 2022-02-04 16:58:26                 NaN
# 2022-01-14 18:34:46                 NaN
# 2022-01-12 10:59:21                 NaN
# 2022-01-01 18:57:57                 NaN
#
#                                                               hashtags
# upload_date
# 2022-02-06 20:22:15  ['vic', 'enp', 'vic_enp', 'brenco', 'partnersh...
# 2022-02-04 16:58:26  ['Cancer', 'cancer_day', 'world_cancer_day', '...
# 2022-01-14 18:34:46  ['Vic', 'Vic_enp', 'engineering', 'exam', 'exa...
# 2022-01-12 10:59:21  ['asegassameggaz', 'newberberyear', 'algerianc...
# 2022-01-01 18:57:57  ['vic', 'enp', 'vic_enp', 'Events', 'growth', ...
#
# [5 rows x 38 columns]

# %% [markdown]
# On procède à la suppression d'un certain nombre de colonnes dont on n'a pas besoin

# %%
posts_df.drop(['height', 'width', 'gating_info', 'fact_check_overall_rating', 'fact_check_information', 'sensitivity_friction_info', 'media_overlay_info', 'media_preview', 'username', 'full_name', 'profile_pic_url', 'profile_pic_url_hd', 'viewer_can_reshare', 'accessibility_caption', 'commenting_disabled_for_viewer', 'id', 'tracking_token', 'tagged_users', 'caption_is_edited', 'has_ranked_comments', 'comments_disabled', 'location'], axis='columns', inplace = True)
posts_df.head()
# Out:
#                      Unnamed: 0    shortcode  \
# upload_date
# 2022-02-06 20:22:15           0  CZpb0SioDg6
# 2022-02-04 16:58:26           1  CZj65qrIY_7
# 2022-01-14 18:34:46           2  CYuBO9VIYAQ
# 2022-01-12 10:59:21           3  CYoDhjtIHox
# 2022-01-01 18:57:57           4  CYMjhsdvvVT
#
#                                                            display_url  \
# upload_date
# 2022-02-06 20:22:15  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
# 2022-02-04 16:58:26  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
# 2022-01-14 18:34:46  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
# 2022-01-12 10:59:21  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
# 2022-01-01 18:57:57  https://instagram.falg2-2.fna.fbcdn.net/v/t51....
#
#                      is_video  \
# upload_date
# 2022-02-06 20:22:15     False
# 2022-02-04 16:58:26     False
# 2022-01-14 18:34:46     False
# 2022-01-12 10:59:21     False
# 2022-01-01 18:57:57      True
#
#                                                                caption  \
# upload_date
# 2022-02-06 20:22:15  [ Partnership ]\n\nThe Vision & Innovation Clu...
# 2022-02-04 16:58:26  [ WORLD CANCER DAY ] \n\n Cancer is the second...
# 2022-01-14 18:34:46  The first stage of the school year is about to...
# 2022-01-12 10:59:21  [ New Berber Year | Yennayer ]\n\nIlmend n ume...
# 2022-01-01 18:57:57  Hello, VICommunity!\n\nThe VIC family expresse...
#
#                      comments   timestamp  likes  viewer_has_liked  \
# upload_date
# 2022-02-06 20:22:15        11  1644175335    165             False
# 2022-02-04 16:58:26         4  1643990306    208              True
# 2022-01-14 18:34:46         9  1642181686    244             False
# 2022-01-12 10:59:21         6  1641981561    370              True
# 2022-01-01 18:57:57       117  1641059877    578              True
#
#                      viewer_has_saved  viewer_has_saved_to_collection  \
# upload_date
# 2022-02-06 20:22:15              True                           False
# 2022-02-04 16:58:26              True                           False
# 2022-01-14 18:34:46              True                           False
# 2022-01-12 10:59:21              True                           False
# 2022-01-01 18:57:57              True                           False
#
#                      viewer_in_photo_of_you  \
# upload_date
# 2022-02-06 20:22:15                   False
# 2022-02-04 16:58:26                   False
# 2022-01-14 18:34:46                   False
# 2022-01-12 10:59:21                   False
# 2022-01-01 18:57:57                   False
#
#                                                              video_url  \
# upload_date
# 2022-02-06 20:22:15                                                NaN
# 2022-02-04 16:58:26                                                NaN
# 2022-01-14 18:34:46                                                NaN
# 2022-01-12 10:59:21                                                NaN
# 2022-01-01 18:57:57  https://z-p4-instagram.falg2-2.fna.fbcdn.net/v...
#
#                     has_audio  video_view_count  \
# upload_date
# 2022-02-06 20:22:15       NaN               NaN
# 2022-02-04 16:58:26       NaN               NaN
# 2022-01-14 18:34:46       NaN               NaN
# 2022-01-12 10:59:21       NaN               NaN
# 2022-01-01 18:57:57      True            4143.0
#
#                                                               hashtags
# upload_date
# 2022-02-06 20:22:15  ['vic', 'enp', 'vic_enp', 'brenco', 'partnersh...
# 2022-02-04 16:58:26  ['Cancer', 'cancer_day', 'world_cancer_day', '...
# 2022-01-14 18:34:46  ['Vic', 'Vic_enp', 'engineering', 'exam', 'exa...
# 2022-01-12 10:59:21  ['asegassameggaz', 'newberberyear', 'algerianc...
# 2022-01-01 18:57:57  ['vic', 'enp', 'vic_enp', 'Events', 'growth', ...

# %%
posts_df.describe()
# Out:
#        Unnamed: 0    comments     timestamp        likes  video_view_count
# count  447.000000  447.000000  4.470000e+02   447.000000         69.000000
# mean   223.000000    3.029083  1.591880e+09   118.212528        893.739130
# std    129.182042    8.223152  3.811458e+07   223.790114       1082.498222
# min      0.000000    0.000000  1.500061e+09    12.000000         28.000000
# 25%    111.500000    0.000000  1.560156e+09    53.500000        244.000000
# 50%    223.000000    0.000000  1.596186e+09    90.000000        571.000000
# 75%    334.500000    3.000000  1.625209e+09   142.500000       1123.000000
# max    446.000000  117.000000  1.644175e+09  4470.000000       5729.000000

# %%
posts_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
posts_df.columns
# Out:
# Index(['shortcode', 'display_url', 'is_video', 'caption', 'comments',
#        'timestamp', 'likes', 'viewer_has_liked', 'viewer_has_saved',
#        'viewer_has_saved_to_collection', 'viewer_in_photo_of_you', 'video_url',
#        'has_audio', 'video_view_count', 'hashtags'],
#       dtype='object')

# %%
plt.style.use('seaborn-darkgrid')
plt.figure()
posts_df['likes'].plot(style='k.', c ='b', figsize=(16,10))
plt.ylim([0,800])
# Out:
# (0.0, 800.0)

# %% [markdown]
# On va maintenant regarder la tendance en moyennant les mensuellement des j'aimes en moyennant la valeur du nombre de mention j'aime

# %%
plt.figure(figsize=(16,10))
posts_df['likes'].plot(style='k.', label="Nombre de mention j'aimes", c ='b')
posts_df['likes'].resample('M').mean().plot(label='Moyenne mensuelle', lw=3, ls=':', alpha = 0.8, c='r')
#posts_df['likes'].resample('W').mean().plot(label='Moyenne hebdomadaire', lw = 2, ls = '--' , alpha = 0.8)
plt.legend()
plt.ylim([0,800])
plt.show()

# %% [markdown]
# On peut Maintenant faire quelques graphiques plus représentatif vis-à-vis du nombre de mentions j'aime sur les posts

# %%
moyenne_annee = posts_df['likes'].resample('Y').mean()
moyenne_mois = posts_df['likes'].resample('M').mean()

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(moyenne_annee)
plt.xlabel("Les années")
plt.ylabel("Nombre de mentions j'aimes en moyenne")
plt.subplot(1,2,2)
plt.plot(moyenne_mois)
plt.xlabel("Les mois")
plt.ylabel("Nombre de mentions j'aimes en moyenne")
plt.show()

# %% [markdown]
# Maintenant en faisant un comparatif sur les mois pour les 3 années d'activités complètes du VIC on observe cela

# %%
moyenne_2021 = list(posts_df['2021']['likes'].resample('M').mean())
moyenne_2020 = list(posts_df['2020']['likes'].resample('M').mean())
moyenne_2019 = list(posts_df['2019']['likes'].resample('M').mean())
mois = range(1,13)
plt.figure(figsize=(12,8))
plt.plot(mois,moyenne_2021, label="Moyenne 2021")
plt.plot(mois,moyenne_2020, label="Moyenne 2020")
plt.plot(mois,moyenne_2019, label="Moyenne 2019")
plt.legend()
plt.xlabel("Les mois")
plt.ylabel("Nombre de mentions j'aimes en moyenne")
plt.show()
# Out:
# <ipython-input-12-f391b6655b5f>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   moyenne_2021 = list(posts_df['2021']['likes'].resample('M').mean())
# <ipython-input-12-f391b6655b5f>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   moyenne_2020 = list(posts_df['2020']['likes'].resample('M').mean())
# <ipython-input-12-f391b6655b5f>:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   moyenne_2019 = list(posts_df['2019']['likes'].resample('M').mean())

# %% [markdown]
# Maintenant on va analyser les habitudes de publications suivant le jour et l'heure de publication
#
# !TODO : Il faut voir comment prendre les données par semaine et par heure et les fusionner pour en faire une heatmap

# %%
plt.hist(posts_df['2021']['likes'].resample('W').agg(['mean']))
# Out:
# <ipython-input-13-aaf796d22b73>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   plt.hist(posts_df['2021']['likes'].resample('W').agg(['mean']))
# (array([43.,  2.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  66.        ,  235.03333333,  404.06666667,  573.1       ,
#          742.13333333,  911.16666667, 1080.2       , 1249.23333333,
#         1418.26666667, 1587.3       , 1756.33333333]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Maintenant on va voir les statistiques des reels

# %%
reels = [
    {"Upload_date" : "10 Jun 2021", "Duration" : 15, "Reach" : 10528, "Plays" : 12201, "Likes" : 549, "Comments" : 37, "Shares" : 471, "Saves" : 27}, 
    {"Upload_date" : "30 Jun 2021", "Duration" : 30, "Reach" : 3063, "Plays" : 3639, "Likes" : 248, "Comments" : 8, "Shares" : 137, "Saves" : 14},
    {"Upload_date" : "13 Jul 2021", "Duration" : 30, "Reach" : 5159, "Plays" : 6184, "Likes" : 351, "Comments" : 9, "Shares" : 241, "Saves" : 18},
    {"Upload_date" : "3 Aug 2021", "Duration" : 30, "Reach" : 3654, "Plays" : 4177, "Likes" : 296, "Comments" : 17, "Shares" : 64, "Saves" : 30},
    {"Upload_date" : "17 Sep 2021", "Duration" : 15, "Reach" : 3510, "Plays" : 4155, "Likes" : 223, "Comments" : 12, "Shares" : 18, "Saves" : 17},
    {"Upload_date" : "25 Oct 2021", "Duration" : 45, "Reach" : 3867, "Plays" : 5161, "Likes" : 246, "Comments" : 18, "Shares" : 11, "Saves" : 12},
    {"Upload_date" : "29 Oct 2021", "Duration" : 18, "Reach" : 2738, "Plays" : 3286, "Likes" : 250, "Comments" : 8, "Shares" : 22, "Saves" : 13},
    {"Upload_date" : "1 Nov 2021", "Duration" : 46, "Reach" : 2294, "Plays" : 3013, "Likes" : 153, "Comments" : 6, "Shares" : 5, "Saves" : 6},
    {"Upload_date" : "1 Jan 2022", "Duration" : 59, "Reach" : 7576, "Plays" : 8557, "Likes" : 575, "Comments" : 117, "Shares" : 228, "Saves" : 36},
    ]
reels = pd.DataFrame(reels)
reels
# Out:
#    Upload_date  Duration  Reach  Plays  Likes  Comments  Shares  Saves
# 0  10 Jun 2021        15  10528  12201    549        37     471     27
# 1  30 Jun 2021        30   3063   3639    248         8     137     14
# 2  13 Jul 2021        30   5159   6184    351         9     241     18
# 3   3 Aug 2021        30   3654   4177    296        17      64     30
# 4  17 Sep 2021        15   3510   4155    223        12      18     17
# 5  25 Oct 2021        45   3867   5161    246        18      11     12
# 6  29 Oct 2021        18   2738   3286    250         8      22     13
# 7   1 Nov 2021        46   2294   3013    153         6       5      6
# 8   1 Jan 2022        59   7576   8557    575       117     228     36

# %% [markdown]
# On va faire un ensemble de visualisation sur les reels :
# - Nombre de likes
# - Nombre de comptes atteint
# - Nombre de fois ou le reels a été joué
# - Nombre de commentaires par reels
# - Nombre de partages
# - Nombre de sauvegarde
#
# Ensuite on va analyser les différences entre les grandeurs :
# - Ration likes / nombre de comptes touchés
# - Ratio partage / nombre de comptes touchés
# - Ration sauvegarde / nombre de comptes touchés
# - Ratio Commentaires / Likes

# %%
plt.figure(figsize=(20,20))
plt.subplot(5,1,1)
plt.plot(reels["Upload_date"],reels["Reach"], label="Reach")
plt.plot(reels["Upload_date"],reels["Plays"], label="Plays")
plt.xlabel("Les reels")
plt.ylabel("Nombre de comptes touchés et de visionnages des reels")
plt.legend()
plt.subplot(5,1,2)
plt.plot(reels["Upload_date"],reels["Likes"])
plt.xlabel("Les reels")
plt.ylabel("Nombre de mentions j'aimes")
plt.subplot(5,1,3)
plt.plot(reels["Upload_date"],reels["Comments"])
plt.xlabel("Les reels")
plt.ylabel("Nombre de commentaires")
plt.subplot(5,1,4)
plt.plot(reels["Upload_date"],reels["Shares"])
plt.xlabel("Les reels")
plt.ylabel("Nombre de partages")
plt.subplot(5,1,5)
plt.plot(reels["Upload_date"],reels["Saves"])
plt.xlabel("Les reels")
plt.ylabel("Nombre de partages")
plt.show()

# %% [markdown]
# Maintenant on observe la démographie de notre communauté

# %%
followers_city_label = 'Algiers', 'Oran', 'Blida', 'Annaba', 'Constantine', 'Autre'
followers_city = [48.3, 2, 1.8, 1.7, 1.3, 44.9]
followers_country_label = 'Algeria', 'France', 'Canada', 'Turkey', 'Spain'
followers_country = [90.3, 6.3, 0.7, 0.3, 0.2]
followers_age_label = '13-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+'
followers_age = [2.3, 70.4, 24.2, 1.5, 0.5, 0.3, 0.5]
followers_men_label = '13-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+'
followers_men = [1.2, 63.3, 31.8, 1.7, 0.4, 0.2, 0.9]
followers_women_label = '13-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+'
followers_women = [2.1, 76.3, 19.4, 1.1, 0.4, 0.2, 0.2]
followers_gender_label = 'Men', 'Women', 'Autre'
followers_gender = [45.7, 54.2, 0.1]

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
plt.pie(followers_city, autopct='%1.1f%%')
plt.title("Répartition par villes")
plt.legend(title='Villes',loc='center left',labels=followers_city_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.subplot(2,3,2)
plt.pie(followers_country, autopct='%1.1f%%')
plt.title("Réparition par pays")
plt.legend(title='Pays',loc='center left', labels=followers_country_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.subplot(2,3,3)
plt.pie(followers_age, autopct='%1.1f%%')
plt.title("Répartition par ages")
plt.legend(title='Ages',loc='center left', labels=followers_age_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.subplot(2,3,4)
plt.pie(followers_men, autopct='%1.1f%%')
plt.title("Ages de la communauté masculine")
plt.legend(title='Ages hommes',loc='center left',labels=followers_men_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.subplot(2,3,5)
plt.pie(followers_women, autopct='%1.1f%%')
plt.title("Ages de la communauté féminine")
plt.legend(title='Ages femmes',loc='center left',labels=followers_women_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.subplot(2,3,6)
plt.pie(followers_gender, autopct='%1.1f%%')
plt.title("Répartition des genres")
plt.legend(title='Genres',loc='center left', labels=followers_gender_label, bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()
